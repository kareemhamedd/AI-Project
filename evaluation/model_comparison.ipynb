# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Model": ["ResNet50", "VGG16", "EfficientNet"],
    "Accuracy": [None, None, None],
    "Precision": [None, None, None],
    "Recall": [None, None, None],
    "F1-Score": [None, None, None]
}

df = pd.DataFrame(data)
df
# Out:
#           Model Accuracy Precision Recall F1-Score
# 0      ResNet50     None      None   None     None
# 1         VGG16     None      None   None     None
# 2  EfficientNet     None      None   None     None

# %%
models = ["ResNet50", "VGG16", "EfficientNet"]
f1_scores = [0, 0, 0]  

plt.bar(models, f1_scores)
plt.title("Model Comparison Based on F1-Score")
plt.ylabel("F1-Score")
plt.xlabel("Model")
plt.show()

# %% [markdown]
# ## Model Comparison Analysis
#
# This section presents a comparison between three CNN architectures:
# ResNet50, VGG16, and EfficientNet using standard evaluation metrics.
#
# The comparison highlights performance differences across models.
# Such differences are mainly due to architectural design and parameter efficiency.

# %% [markdown]
# ## Confusion Matrix Analysis
#
# The confusion matrix indicates that the models correctly classify most samples.
# Misclassifications mainly occur between visually similar celebrities, which is
# expected in face recognition tasks. This suggests that errors are caused by
# similar facial features rather than random predictions.

# %% [markdown]
# ## Grad-CAM Analysis
#
# Grad-CAM visualizations show that the model focuses on important facial regions
# such as the eyes, nose, and mouth. This indicates that the model relies on
# meaningful facial features instead of background information, which improves
# the explainability of the predictions.
